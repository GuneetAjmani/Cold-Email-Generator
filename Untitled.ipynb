# %%
pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.3.7-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\gunee\anaconda3\lib\site-packages (from langchain) (1.4.32)
# Collecting langchain-core<0.4.0,>=0.3.15
#   Downloading langchain_core-0.3.15-py3-none-any.whl (408 kB)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\gunee\anaconda3\lib\site-packages (from langchain) (4.0.1)
# Collecting langsmith<0.2.0,>=0.1.17
#   Downloading langsmith-0.1.142-py3-none-any.whl (306 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0
#   Downloading langchain_text_splitters-0.3.2-py3-none-any.whl (25 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\gunee\anaconda3\lib\site-packages (from langchain) (2.27.1)
# Requirement already satisfied: numpy<2,>=1 in c:\users\gunee\anaconda3\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\gunee\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\gunee\anaconda3\lib\site-packages (from langchain) (8.2.3)
# Collecting pydantic<3.0.0,>=2.7.4
#   Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.10.10-cp39-cp39-win_amd64.whl (381 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gunee\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gunee\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Collecting yarl<2.0,>=1.12.0
#   Downloading yarl-1.17.1-cp39-cp39-win_amd64.whl (90 kB)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gunee\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (5.1.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gunee\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\gunee\anaconda3\lib\site-packages (from async-timeout<5.0.0,>=4.0.0->langchain) (4.11.0)
# Collecting packaging<25,>=23.2
#   Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Collecting orjson<4.0.0,>=3.9.14
#   Downloading orjson-3.10.11-cp39-none-win_amd64.whl (136 kB)
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
# Requirement already satisfied: anyio in c:\users\gunee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.5.0)
# Requirement already satisfied: sniffio in c:\users\gunee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.0)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
# Requirement already satisfied: idna in c:\users\gunee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.3)
# Requirement already satisfied: certifi in c:\users\gunee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (2021.10.8)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.23.4
#   Downloading pydantic_core-2.23.4-cp39-none-win_amd64.whl (1.9 MB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gunee\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gunee\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.9)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\gunee\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.2.0-cp39-cp39-win_amd64.whl (45 kB)
# Installing collected packages: h11, pydantic-core, httpcore, annotated-types, requests-toolbelt, pydantic, orjson, jsonpointer, httpx, propcache, packaging, langsmith, jsonpatch, yarl, langchain-core, aiohappyeyeballs, langchain-text-splitters, aiohttp, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.6.3
#     Uninstalling yarl-1.6.3:
#       Successfully uninstalled yarl-1.6.3
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.1
#     Uninstalling aiohttp-3.8.1:
#       Successfully uninstalled aiohttp-3.8.1
# Successfully installed aiohappyeyeballs-2.4.3 aiohttp-3.10.10 annotated-types-0.7.0 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.7 langchain-core-0.3.15 langchain-text-splitters-0.3.2 langsmith-0.1.142 orjson-3.10.11 packaging-24.2 propcache-0.2.0 pydantic-2.9.2 pydantic-core-2.23.4 requests-toolbelt-1.0.0 yarl-1.17.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 1.13.5 requires pywinpty<2; os_name == "nt", but you have pywinpty 2.0.2 which is incompatible.

# %%
pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-0.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\gunee\anaconda3\lib\site-packages (from langchain-groq) (0.3.15)
# Collecting groq<1,>=0.4.1
#   Downloading groq-0.11.0-py3-none-any.whl (106 kB)
# Collecting distro<2,>=1.7.0
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: sniffio in c:\users\gunee\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\gunee\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\gunee\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (3.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\gunee\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (2.9.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\gunee\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (0.27.2)
# Requirement already satisfied: idna>=2.8 in c:\users\gunee\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.3)
# Requirement already satisfied: httpcore==1.* in c:\users\gunee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.6)
# Requirement already satisfied: certifi in c:\users\gunee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2021.10.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gunee\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\gunee\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq) (24.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\gunee\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq) (0.1.142)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\gunee\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq) (1.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\gunee\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq) (8.2.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\gunee\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq) (6.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gunee\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain-groq) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\gunee\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (1.0.0)
# Requirement already satisfied: requests<3,>=2 in c:\users\gunee\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (2.27.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\gunee\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (3.10.11)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gunee\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\gunee\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.23.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gunee\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gunee\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (1.26.9)
# Installing collected packages: distro, groq, langchain-groq
# Successfully installed distro-1.9.0 groq-0.11.0 langchain-groq-0.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.5.18-py3-none-any.whl (615 kB)
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.2.0-cp39-abi3-win_amd64.whl (151 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\users\gunee\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
# Collecting posthog>=2.4.0
#   Downloading posthog-3.7.0-py2.py3-none-any.whl (54 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\gunee\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\gunee\anaconda3\lib\site-packages (from chromadb) (0.27.2)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl (18 kB)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-5.0.1-cp39-cp39-win_amd64.whl (39 kB)
# Collecting typer>=0.9.0
#   Downloading typer-0.13.0-py3-none-any.whl (44 kB)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.19.2-cp39-cp39-win_amd64.whl (11.1 MB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\gunee\anaconda3\lib\site-packages (from chromadb) (4.11.0)
# Collecting fastapi>=0.95.2
#   Downloading fastapi-0.115.4-py3-none-any.whl (94 kB)
# Collecting importlib-resources
#   Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Collecting build>=1.0.3
#   Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Collecting tqdm>=4.65.0
#   Downloading tqdm-4.67.0-py3-none-any.whl (78 kB)
# Collecting tokenizers>=0.13.2
#   Downloading tokenizers-0.20.3-cp39-none-win_amd64.whl (2.4 MB)
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.32.0-py3-none-any.whl (63 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\gunee\anaconda3\lib\site-packages (from chromadb) (2.9.2)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\gunee\anaconda3\lib\site-packages (from chromadb) (3.10.11)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.28.1-py3-none-any.whl (118 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\gunee\anaconda3\lib\site-packages (from chromadb) (6.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\gunee\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.28.1-py3-none-any.whl (64 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\gunee\anaconda3\lib\site-packages (from chromadb) (1.63.0)
# Collecting chroma-hnswlib==0.7.6
#   Downloading chroma_hnswlib-0.7.6-cp39-cp39-win_amd64.whl (151 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.49b1-py3-none-any.whl (12 kB)
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: tomli>=1.1.0 in c:\users\gunee\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.2)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: colorama in c:\users\gunee\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.4)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\gunee\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (4.11.3)
# Requirement already satisfied: packaging>=19.1 in c:\users\gunee\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting starlette<0.42.0,>=0.40.0
#   Downloading starlette-0.41.2-py3-none-any.whl (73 kB)
# Requirement already satisfied: httpcore==1.* in c:\users\gunee\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: certifi in c:\users\gunee\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2021.10.8)
# Requirement already satisfied: anyio in c:\users\gunee\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: sniffio in c:\users\gunee\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: idna in c:\users\gunee\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.3)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gunee\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.16.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# streamlit 1.33.0 requires protobuf<5,>=3.20, but you have protobuf 5.28.3 which is incompatible.
# Requirement already satisfied: zipp>=0.5 in c:\users\gunee\anaconda3\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.7.0)
# Requirement already satisfied: requests in c:\users\gunee\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.27.1)
# Collecting durationpy>=0.7
#   Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\gunee\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.9)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\gunee\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Collecting oauthlib>=3.2.2
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\gunee\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\gunee\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.33.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\gunee\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gunee\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gunee\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.7.2)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\gunee\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (61.2.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\gunee\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.2.2)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: protobuf in c:\users\gunee\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: flatbuffers in c:\users\gunee\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: sympy in c:\users\gunee\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.10.1)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata>=4.6
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\gunee\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.12.1)
# Collecting zipp>=0.5
#   Downloading zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Collecting opentelemetry-proto==1.28.1
#   Downloading opentelemetry_proto-1.28.1-py3-none-any.whl (55 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\gunee\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.53.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.1
#   Downloading opentelemetry_exporter_otlp_proto_common-1.28.1-py3-none-any.whl (18 kB)
# Collecting grpcio>=1.58.0
#   Downloading grpcio-1.67.1-cp39-cp39-win_amd64.whl (4.4 MB)
# Collecting protobuf
#   Downloading protobuf-5.28.3-cp39-cp39-win_amd64.whl (431 kB)
# Collecting opentelemetry-instrumentation==0.49b1
#   Downloading opentelemetry_instrumentation-0.49b1-py3-none-any.whl (30 kB)
# Collecting opentelemetry-semantic-conventions==0.49b1
#   Downloading opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl (159 kB)
# Collecting opentelemetry-util-http==0.49b1
#   Downloading opentelemetry_util_http-0.49b1-py3-none-any.whl (6.9 kB)
# Collecting opentelemetry-instrumentation-asgi==0.49b1
#   Downloading opentelemetry_instrumentation_asgi-0.49b1-py3-none-any.whl (16 kB)
# Collecting asgiref~=3.0
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gunee\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gunee\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\gunee\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gunee\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (2.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\gunee\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gunee\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gunee\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Collecting huggingface-hub<1.0,>=0.16.4
#   Downloading huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Requirement already satisfied: filelock in c:\users\gunee\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.6.0)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: click>=8.0.0 in c:\users\gunee\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\gunee\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Collecting httptools>=0.5.0
#   Downloading httptools-0.6.4-cp39-cp39-win_amd64.whl (89 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.24.0-cp39-none-win_amd64.whl (277 kB)
# Collecting websockets>=10.4
#   Downloading websockets-14.0-cp39-cp39-win_amd64.whl (162 kB)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting pyreadline3
#   Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\gunee\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (PEP 517): started
#   Building wheel for pypika (PEP 517): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53835 sha256=4b737666188c2c182709befc1b2ec4cefa762880c1e8c7b6f2a803dd0a81b3d5
#   Stored in directory: c:\users\gunee\appdata\local\pip\cache\wheels\f7\02\64\d541eac67ec459309d1fb19e727f58ecf7ffb4a8bf42d4cfe5
# Successfully built pypika
# Installing collected packages: zipp, importlib-metadata, deprecated, opentelemetry-api, pyreadline3, protobuf, opentelemetry-semantic-conventions, tqdm, opentelemetry-util-http, opentelemetry-proto, opentelemetry-instrumentation, oauthlib, humanfriendly, fsspec, asgiref, websockets, watchfiles, uvicorn, starlette, shellingham, requests-oauthlib, pyproject-hooks, opentelemetry-sdk, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-common, monotonic, huggingface-hub, httptools, grpcio, durationpy, coloredlogs, backoff, typer, tokenizers, pypika, posthog, overrides, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, onnxruntime, mmh3, kubernetes, importlib-resources, fastapi, chroma-hnswlib, build, bcrypt, chromadb
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.7.0
#     Uninstalling zipp-3.7.0:
#       Successfully uninstalled zipp-3.7.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.2.0
#     Uninstalling fsspec-2022.2.0:
#       Successfully uninstalled fsspec-2022.2.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.63.0
#     Uninstalling grpcio-1.63.0:
#       Successfully uninstalled grpcio-1.63.0
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.5.18 coloredlogs-15.0.1 deprecated-1.2.14 durationpy-0.9 fastapi-0.115.4 fsspec-2024.10.0 grpcio-1.67.1 httptools-0.6.4 huggingface-hub-0.26.2 humanfriendly-10.0 importlib-metadata-8.5.0 importlib-resources-6.4.5 kubernetes-31.0.0 mmh3-5.0.1 monotonic-1.6 oauthlib-3.2.2 onnxruntime-1.19.2 opentelemetry-api-1.28.1 opentelemetry-exporter-otlp-proto-common-1.28.1 opentelemetry-exporter-otlp-proto-grpc-1.28.1 opentelemetry-instrumentation-0.49b1 opentelemetry-instrumentation-asgi-0.49b1 opentelemetry-instrumentation-fastapi-0.49b1 opentelemetry-proto-1.28.1 opentelemetry-sdk-1.28.1 opentelemetry-semantic-conventions-0.49b1 opentelemetry-util-http-0.49b1 overrides-7.7.0 posthog-3.7.0 protobuf-5.28.3 pypika-0.48.9 pyproject-hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 shellingham-1.5.4 starlette-0.41.2 tokenizers-0.20.3 tqdm-4.67.0 typer-0.13.0 uvicorn-0.32.0 watchfiles-0.24.0 websockets-14.0 zipp-3.20.2

# %%
pip install protobuf==3.20.3
# Out:
# Collecting protobuf==3.20.3Note: you may need to restart the kernel to use updated packages.
#   Downloading protobuf-3.20.3-cp39-cp39-win_amd64.whl (904 kB)
# Installing collected packages: protobuf
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\gunee\\anaconda3\\Lib\\site-packages\\google\\~upb\\_message.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.28.3
#     Uninstalling protobuf-5.28.3:
#       Successfully uninstalled protobuf-5.28.3

# %%
pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.3.5-py3-none-any.whl (2.4 MB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\gunee\anaconda3\lib\site-packages (from langchain_community) (0.1.142)
# Requirement already satisfied: langchain<0.4.0,>=0.3.6 in c:\users\gunee\anaconda3\lib\site-packages (from langchain_community) (0.3.7)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\gunee\anaconda3\lib\site-packages (from langchain_community) (6.0)
# Collecting dataclasses-json<0.7,>=0.5.7
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0
#   Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: numpy<2,>=1 in c:\users\gunee\anaconda3\lib\site-packages (from langchain_community) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0
#   Downloading pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\gunee\anaconda3\lib\site-packages (from langchain_community) (2.27.1)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\gunee\anaconda3\lib\site-packages (from langchain_community) (8.2.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\gunee\anaconda3\lib\site-packages (from langchain_community) (3.10.10)
# Requirement already satisfied: SQLAlchemy<2.0.36,>=1.4 in c:\users\gunee\anaconda3\lib\site-packages (from langchain_community) (1.4.32)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\gunee\anaconda3\lib\site-packages (from langchain_community) (0.3.15)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\gunee\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gunee\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (5.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\gunee\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\gunee\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gunee\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gunee\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gunee\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\gunee\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (4.11.0)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\gunee\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.6->langchain_community) (2.9.2)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\gunee\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.6->langchain_community) (0.3.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\gunee\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_community) (24.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\gunee\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_community) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gunee\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain_community) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\gunee\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\gunee\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (3.10.11)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\gunee\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (0.27.2)
# Requirement already satisfied: sniffio in c:\users\gunee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.2.0)
# Requirement already satisfied: idna in c:\users\gunee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (3.3)
# Requirement already satisfied: anyio in c:\users\gunee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (3.5.0)
# Requirement already satisfied: certifi in c:\users\gunee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (2021.10.8)
# Requirement already satisfied: httpcore==1.* in c:\users\gunee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gunee\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gunee\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.6->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\gunee\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.6->langchain_community) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\gunee\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gunee\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gunee\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\gunee\anaconda3\lib\site-packages (from SQLAlchemy<2.0.36,>=1.4->langchain_community) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\gunee\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (0.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\gunee\anaconda3\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (0.2.0)
# Installing collected packages: typing-inspect, marshmallow, pydantic-settings, httpx-sse, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.5 marshmallow-3.23.1 pydantic-settings-2.6.1 typing-inspect-0.9.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gunee\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gunee\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gunee\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gunee\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gunee\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gunee\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gunee\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gunee\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gunee\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gunee\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gunee\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gunee\anaconda3\lib\site-packages)
